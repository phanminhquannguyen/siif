# %%
import psycopg2

# %%
# Connection details
connection_string = "postgresql://postgres:[YOUR-PASSWORD]@db.lshtgdpdskhqqxdcwpjo.supabase.co:5432/postgres"

# --- Connect and run query ---
conn = psycopg2.connect(connection_string)
print("✅ Connected successfully!")

cur = conn.cursor()
cur.execute("SELECT NOW();")
print("Server time:", cur.fetchone())

cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 5
#       2 connection_string = "postgresql://postgres:[YOUR-PASSWORD]@db.lshtgdpdskhqqxdcwpjo.supabase.co:5432/postgres"
#       4 # --- Connect and run query ---
# ----> 5 conn = psycopg2.connect(connection_string)
#       6 print("✅ Connected successfully!")
#       8 cur = conn.cursor()
#
# File ~/miniforge3/envs/siif_venv/lib/python3.12/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# ...
